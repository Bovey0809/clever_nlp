# %%
import pandas as pd

data_stage2 = pd.read_csv("./wordnet_results-12-01-2022-14-52-02.csv")

data_stage1 = pd.read_csv("./wordnet_results_stage_1.csv")

data_stage2.drop(columns='Unnamed: 0', inplace=True)

data_stage1.drop(columns='Unnamed: 0', inplace=True)

# %%
import random
left = random.randint(0, 14000)
id_range = [left, left+5]

# %%
data_stage2[id_range[0]:id_range[1]]
# Out:
#                                             norm_recall  \
# 9554  ['[unused415]', '[unused309]', '[unused162]', ...
# 9555  ['william', 'wilson', '1950', 'robert', '1986'...
# 9556  ['[unused339]', '[unused92]', '[unused706]', '...
# 9557  ['chocolate', 'coffee', 'candy', 'beer', '1983...
# 9558  ['excellent', 'elegant', '1880', 'exceptional'...
#
#                                           norm_distance  \
# 9554  [0.739975   0.74681085 0.73194766 ... 0.971511...
# 9555  [1.2550981 1.2579967 1.2452495 ... 1.4240305 1...
# 9556  [0.72227204 0.7298262  0.7229116  ... 0.984885...
# 9557  [1.687299  1.6877829 1.68095   ... 1.9395543 1...
# 9558  [1.2478602 1.2466228 1.2497206 ... 1.5121714 1...
#
#                                              cos_recall  \
# 9554  ['1808', '1733', '1612', '[unused309]', '[unus...
# 9555  ['1782', '1739', 'exiles', '1783', '1747', '18...
# 9556  ['1679', '1726', 'prophet', '[unused339]', '[u...
# 9557  ['cocoa', 'candy', 'coffee', 'cookies', 'biscu...
# ...

# %%
data_stage1[id_range[0]:id_range[1]]
# Out:
#                                             norm_recall  \
# 9554  ['[unused415]', '[unused309]', '[unused162]', ...
# 9555  ['soldiers', 'william', 'troops', 'army', '198...
# 9556  ['[unused339]', '[unused92]', '[unused706]', '...
# 9557  ['chocolate', 'coffee', 'beer', 'candy', 'food...
# 9558  ['ideal', '1890', 'excellent', 'ideals', '1882...
#
#                                           norm_distance  \
# 9554  [0.739975   0.74681085 0.73194766 ... 0.971511...
# 9555  [1.2550981 1.2579967 1.2452495 ... 1.4240305 1...
# 9556  [0.72227204 0.7298262  0.7229116  ... 0.984885...
# 9557  [1.687299  1.6877829 1.68095   ... 1.9395543 1...
# 9558  [1.2478602 1.2466228 1.2497206 ... 1.5121714 1...
#
#                                              cos_recall  \
# 9554  ['1704', '1797', '1808', '1733', '1727', '1737...
# 9555  ['1782', '1739', 'exiles', '1660', '1783', '17...
# 9556  ['1728', '1679', '1726', '[unused339]', '[unus...
# 9557  ['coffee', 'cocoa', 'dessert', 'vodka', 'candy...
# ...

# %%
data_stage1_drop_def = data_stage1.drop(columns='definition')

# %%
data_stage1.melt(id_vars='word')
# Out:
#                word     variable  \
# 0         exploited  norm_recall
# 1            stucco  norm_recall
# 2          southern  norm_recall
# 3            barrio  norm_recall
# 4          humidity  norm_recall
# ...             ...          ...
# 101565    biography   definition
# 101566       deacon   definition
# 101567        fully   definition
# 101568  advertising   definition
# 101569        minus   definition
#
#                                                     value
# 0       ['[unused845]', '[unused230]', '[unused842]', ...
# 1       ['concrete', 'sandstone', '1967', 'marble', '1...
# 2       ['southern', 'south', 'northern', 'north', 'ea...
# 3       ['spanish', 'portuguese', '1976', '1977', '198...
# 4       ['moisture', '1890', '1858', '1883', '1878', '...
# ...                                                   ...
# 101565  an account of the series of events making up a...
# 101566       a Protestant layman who assists the minister
# ...
